# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281_2023/blob/main/docs/labs/lab_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°05

# %% [markdown]
# ## Problema 01
# <img src="https://drive.google.com/uc?export=view&id=1Ha4ZjgvrlWHQ5vV_VydBkxiFXdgDn8TT" width = "200" align="center"/>

# %% [markdown]
# El **Iris dataset** es un conjunto de datos que contine una  muestras de tres especies de Iris (Iris setosa, Iris virginica e Iris versicolor). Se midió cuatro rasgos de cada muestra: el largo y ancho del sépalo y pétalo, en centímetros.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
# librerias

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)  # Ver más columnas de los dataframes


# Ver gráficos de matplotlib en jupyter notebook/lab
# %matplotlib inline

# %%
# cargar datos
data = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281_2022/main/labs/lab_05/data/iris_contaminados.csv")
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           4.4          3.2           1.3          3.0      setosa
# 1           7.2          3.6           6.1          2.5   virginica
# 2           6.3          3.3           6.0          2.5   VIRGINICA
# 3           6.7          3.3           5.7          2.5   virginica
# 4           6.3          3.4           5.6          2.4   virginica

# %% [markdown]
# ### Bases del experimento
#
# Lo primero es identificar las variables que influyen en el estudio y la naturaleza de esta.
#
# * **species**:
#     * Descripción: Nombre de la especie de Iris.
#     * Tipo de dato: *string*
#     * Limitantes: solo existen tres tipos (setosa, virginia y versicolor).
# * **sepalLength**:
#     * Descripción: largo del sépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 4.0 y 7.0 cm.
# * **sepalWidth**:
#     * Descripción: ancho del sépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 2.0 y 4.5 cm.
# * **petalLength**:
#     * Descripción: largo del pétalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 1.0 y 7.0 cm.
# * **petalWidth**:
#     * Descripción: ancho del pépalo.
#     * Tipo de dato: *float*.
#     * Limitantes: los valores se encuentran entre 0.1 y 2.5 cm.

# %% [markdown]
# Su objetivo es realizar un correcto **E.D.A.**, para esto debe seguir las siguientes intrucciones:

# %% [markdown]
# 1. Realizar un conteo de elementos de la columna **species** y corregir según su criterio. Reemplace por "default" los valores `nan`.

# %%
#Corregir las mayusculas por minusculas
data['species'] = data['species'].str.lower()

# Corregir los valores NaN
data['species'].fillna('default', inplace=True)

conteo_nan = data['species'].isna().sum()

print(f'Número de valores NaN en la columna "species": {conteo_nan}')

#Se corrigen espacios en blanco (inicio y final)
data['species'] = data['species'].str.strip()

print("\n")

# Contar los elementos en la columna 'species'
cont_species = data['species'].value_counts()

# Mostrar el conteo de elementos
print(cont_species)
# Out:
# Número de valores NaN en la columna "species": 0
#
#
# setosa        50
# virginica     50
# versicolor    49
# default        1
# Name: species, dtype: int64

# %% [markdown]
# 2. Realizar un gráfico de box-plot sobre el largo y ancho de los petalos y sépalos. Reemplace por **0** los valores nan.

# %%
# Se empieza reemplazando los valores NaN por 0
name_columns = ['sepal_length','sepal_width','petal_length','petal_width']

data[name_columns] = data[name_columns].fillna(0)

# Se crea gráfico de box-plot utilizando seaborn
sns.boxplot(data=data[name_columns])

plt.title("Box-Plot de Largo y Ancho de Pétalos y Sépalos")
plt.show()

# %% [markdown]
# 3. Anteriormente se define un rango de valores válidos para los valores del largo y ancho de los petalos y sépalos. Agregue una columna denominada **label**  que identifique cuál de estos valores esta fuera del rango de valores válidos.

# %%
valid_range = {'sepal_length': (4.0,7.0), 'sepal_width': (2.0,4.5), 'petal_length': (1.0,7.0), 'petal_width': (0.1,2.5)}

#Se agrega la columna 'label' para identificar los valores fuera del rango válido
for feature, (min_val,max_val) in valid_range.items():
  data['label'] = data.apply(lambda row: 'out of range' if row[feature] < min_val or row[feature] > max_val else '', axis=1)

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species  \
# 0           4.4          3.2           1.3          3.0     setosa
# 1           7.2          3.6           6.1          2.5  virginica
# 2           6.3          3.3           6.0          2.5  virginica
# 3           6.7          3.3           5.7          2.5  virginica
# 4           6.3          3.4           5.6          2.4  virginica
#
#           label
# 0  out of range
# 1
# 2
# 3
# 4

# %% [markdown]
# 4. Realice un gráfico de *sepal_length* vs *petal_length* y otro de *sepal_width* vs *petal_width* categorizados por la etiqueta **label**. Concluya sus resultados.

# %%
#Se grafica sepal_length vs petal length
plt.figure(figsize=(8,6))
sns.scatterplot(data=data, x= 'sepal_length',y= 'petal_length', hue= 'label', palette='Set2')

#Se grafica
plt.title('Sepal Length vs Petal Length (Categorizado por Label)')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()

# %% [markdown]
# 5. Filtre los datos válidos y realice un gráfico de *sepal_length* vs *petal_length* categorizados por la etiqueta **species**.

# %%
# Se filtran los datos válidos
filtered_data = data.copy().loc[lambda x: x['species']!= 'default']
for feature, (min_val, max_val) in valid_range.items():
  filtered_data = filtered_data[(filtered_data[feature] >= min_val) & (filtered_data[feature] <= max_val)]

# Se procede a graficar
plt.figure(figsize=(8,6))
sns.scatterplot(data=filtered_data, x='sepal_length', y='petal_length', hue='species', palette='Set2')
plt.title('Sepal Length vs Petal Length (Categorizado por Species)')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.show()
